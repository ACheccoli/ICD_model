# %%
import maboss
import matplotlib.pyplot as plt
import pandas as pd

# %%
table = pd.read_csv('sim_2021-05-04.csv')
table.head()
# Out:
#    Unnamed: 0  PopRatio     NFIL3     HMGB1  preCTL    moDC       YY1  \
# 0           0  1.000000  0.002871  0.051407  0.8609  0.0238  0.317711
# 1           1  0.871788  0.005152  0.093901  0.8621  0.0233  0.398277
# 2           2  0.859708  0.007442  0.131614  0.8586  0.0229  0.467549
# 3           3  0.854782  0.010465  0.177733  0.8637  0.0236  0.535653
# 4           4  0.852207  0.012226  0.211342  0.8627  0.0234  0.588648
#
#        SHIP      Tbet       VAV  TNFRs_L  TIGIT_L      PLCG     FOXP3  \
# 0  0.017544  0.385808  0.356364   0.2304   0.4226  0.016676  0.360339
# 1  0.067005  0.456517  0.456601   0.2305   0.4190  0.020051  0.477060
# 2  0.119793  0.531844  0.513213   0.2307   0.4216  0.020370  0.488972
# 3  0.163024  0.592374  0.545663   0.2304   0.4186  0.022100  0.475645
# 4  0.191473  0.627420  0.560101   0.2305   0.4210  0.021717  0.466488
#
#       TNFRs   IL1BR  PKC_teta  LAG3_L   Ca_NFAT  a_cDC1      IL10   Tumor  \
# ...

# %%
plt.plot(table['PopRatio']*table[''])
plt.plot(table['PopRatio']*table[''])
